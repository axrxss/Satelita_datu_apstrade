# %% [markdown]
# # **Sentinel-2 satellite data processing workshop**
#
# In this workshop, participants will delve into the world of satellite data processing, focusing on Sentinel-2 imagery. The primary data source for this workshop will be the Copernicus Open Access Hub (https://dataspace.copernicus.eu/), a base source for accessing Sentinel satellite data.
#
# This workshop aims to provide a hands-on experience for participants, encuraging them to harness the Earth Observation data for diverse applications, from environmental monitoring to agricultural assessments.
#
# The participants should create an account at https://dataspace.copernicus.eu/
#
# [Access the Riga border shape file here](https://drive.google.com/drive/folders/1bcwNjGeElBsidiNVyqJ32ZivWjaRqd4r?usp=sharing)

# %%
! pip install rasterio rasterstats -q

# %%
import os
import re
import sys
import glob
from pathlib import Path

import requests
import json
import xml.etree.ElementTree as ET
import certifi

import pandas as pd
import numpy as np
import rasterio
from rasterio.mask import mask
from rasterio.plot import show
from rasterio.windows import Window
import matplotlib.pyplot as plt
import matplotlib.image
import folium
import cv2
import geopandas as gpd
from rasterstats import zonal_stats
from pyproj import Proj, transform

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Following the installation and import of libraries, we proceed to explore the data catalog using specific parameters. These include the satellite name, product level (S2MSI2A for surface reflectance), AOI (either point or polygon), and the start and end dates.

# %%
url_dataspace = "https://catalogue.dataspace.copernicus.eu/odata/v1"

# Filtering
satellite = "SENTINEL-2"
level = "S2MSI2A"
cloud_cover_max = 0.2

aoi_point ="POINT (24.1057 56.9483)" #The geographic reference for our area of interest

start_date = "2023-09-21"
end_date = "2023-09-22"
start_date_full =start_date+"T00:00:00.000Z"
end_date_full = end_date +"T00:00:00.000Z"

# %% [markdown]
# With these parameters, we can submit a query to retrieve a list of available images. Ensure that the dataframe has been filtered to include only products with a status of “online”:

# %%
query = f"{url_dataspace}/Products?$filter=Collection/Name eq '{satellite}' and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'productType' and att/OData.CSC.StringAttribute/Value eq '{level}') and OData.CSC.Intersects(area=geography'SRID=4326;{aoi_point}') and ContentDate/Start gt {start_date_full} and ContentDate/Start lt {end_date_full}"
response = requests.get(query).json()
result = pd.DataFrame.from_dict(response["value"])

# Filter records where 'online' column is True
result = result[result['Online'] == True]

# print first 10 results
result.head(10)
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  1de62670-72bc-42dc-9e42-1c0c7c5d8ba9
# 1  application/octet-stream  25708026-43f7-45e0-9a16-37fda7a2df1f
#
#                                                 Name  \
# 0  S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_2...
# 1  S2A_MSIL2A_20230921T094031_N0509_R036_T34VFJ_2...
#
#                 ContentType  ContentLength                OriginDate  \
# 0  application/octet-stream     1103539805  2023-09-21T17:21:00.553Z
# 1  application/octet-stream      983725792  2023-09-21T17:16:30.386Z
#
#             PublicationDate          ModificationDate  Online EvictionDate  \
# 0  2023-09-21T17:27:50.618Z  2023-09-21T17:28:11.021Z    True
# 1  2023-09-21T17:27:30.796Z  2023-09-21T17:27:45.705Z    True
#
#                                               S3Path  \
# 0  /eodata/Sentinel-2/MSI/L2A/2023/09/21/S2A_MSIL...
# 1  /eodata/Sentinel-2/MSI/L2A/2023/09/21/S2A_MSIL...
#
#                                             Checksum  \
# 0  [{'Value': '5604fae0921e3564bfd27e42b6953dd4',...
# 1  [{'Value': 'ace53df9e562f9100afdc89581a48761',...
#
#                                          ContentDate  \
# 0  {'Start': '2023-09-21T09:40:31.024Z', 'End': '...
# 1  {'Start': '2023-09-21T09:40:31.024Z', 'End': '...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((23.6438298900325...
# 1  geography'SRID=4326;POLYGON ((22.6793206704832...
#
#                                         GeoFootprint
# 0  {'type': 'Polygon', 'coordinates': [[[23.64382...
# 1  {'type': 'Polygon', 'coordinates': [[[22.67932...

# %% [markdown]
# After obtaining a list of available images, the next steps involve generating a token using our credentials, establishing a session, and downloading the metadata. For surface reflectance products, we’ll download MTD_MSIL2A.xml.

# %%
#Login info
username = ''
password = ''


auth_server_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
data = {
    "client_id": "cdse-public",
    "grant_type": "password",
    "username": username,
    "password": password,
}

response = requests.post(auth_server_url, data=data, verify=True, allow_redirects=False)
access_token = json.loads(response.text)["access_token"]
# Establish session
session = requests.Session()
session.headers["Authorization"] = f"Bearer {access_token}"

product_row_id = 0   # 0 for the first product in the list
product_id = result.iloc[product_row_id, 1]
print(product_id)
product_name = result.iloc[product_row_id, 2]
print(product_name)

url_MTD = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes(MTD_MSIL2A.xml)/$value"
response = session.get(url_MTD, allow_redirects=False)
while response.status_code in (301, 302, 303, 307):
    url_MTD_location = response.headers["Location"]
    response = session.get(url_MTD_location, allow_redirects=False)

file = session.get(url_MTD_location, verify=False, allow_redirects=True)

# Save the product in home directory
outfile = Path("/content/MTD_MSIL2A.xml")
outfile.write_bytes(file.content)
# Out:
# 1de62670-72bc-42dc-9e42-1c0c7c5d8ba9
# S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE
# 54859

# %% [markdown]
# After executing these lines, you should find the metadata file in your folder. In the following lines, we will read the metadata to identify the file path of each Sentinel-2 band.

# %%
# Pass the path of the xml document
tree = ET.parse(str(outfile))
# get the parent tag
root = tree.getroot()

# Get the location of individual bands in Sentinel-2 granule
band_path = []
band_path.append(f"{product_name}/{root[0][0][12][0][0][0].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][1].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][2].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][3].text}.jp2".split("/"))

# %% [markdown]
# In this example, we will download the red, green, blue, and NIR bands. You can modify the last indices to read other bands. To identify the band locations, you can use the “band_path” command

# %%
band_path
# Out:
# [['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B02_10m.jp2'],
#  ['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B03_10m.jp2'],
#  ['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B04_10m.jp2'],
#  ['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B08_10m.jp2']]

# %% [markdown]
# Once all the bands are located, you can download them one by one using the following lines:

# %%
# Build the url
for band_node in band_path:
    url_full = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes({band_node[1]})/Nodes({band_node[2]})/Nodes({band_node[3]})/Nodes({band_node[4]})/Nodes({band_node[5]})/$value"
    #print(url_full)
    response = session.get(url_full, allow_redirects=False)
    while response.status_code in (301, 302, 303, 307):
        url_full_location = response.headers["Location"]
        response = session.get(url_full_location, allow_redirects=False)
    file = session.get(url_full_location, verify=False, allow_redirects=True)
    # Save the product
    outfile =Path("/content/"+band_node[5])
    outfile.write_bytes(file.content)
    print("Saved:", band_node[5])
# Out:
# Saved: T35VLD_20230921T094031_B02_10m.jp2
# Saved: T35VLD_20230921T094031_B03_10m.jp2
# Saved: T35VLD_20230921T094031_B04_10m.jp2
# Saved: T35VLD_20230921T094031_B08_10m.jp2

# %% [markdown]
# Until now, we have only downloaded the raw red, blue, green, and NIR bands of the Sentinel-2 satellites for our AOI point. In this section, we will read our AOI polygon, read each band in the “jp2” format, convert the AOI projection to match the “jp2” file’s projection, clip each band for our AOI polygon, convert each band to Geotiff, stack the GeoTIFF files, export the stacked file, and visualize it in RGB:

# %%
# Read the shapefile
aoi_geom = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp')

# Get a list of input files
input_files = glob.glob('T35VLD_*_B0[2-8]_10m.jp2')
input_files = sorted(input_files, reverse=True)
print(input_files)

# Read the CRS from one of the input files
with rasterio.open(input_files[0]) as src:
    input_crs = src.crs

# Convert the AOI polygon to the input CRS
aoi_geom = aoi_geom.to_crs(input_crs)

band_mapping = {
    "B02": "blue",
    "B03": "green",
    "B04": "red",
    "B08": "infra-red",
}

# Clip and save each band individually
output_files = []
for i, input_file in enumerate(input_files):
    band_name = input_file.split('_')[-2].split('.')[0]
    with rasterio.open(input_file) as src:
        # Clip the image
        out_image, out_transform = mask(src, aoi_geom.geometry, crop=True)

        # Update the metadata
        out_meta = src.meta.copy()
        out_meta.update({"driver": "GTiff",
                         "height": out_image.shape[1],
                         "width": out_image.shape[2],
                         "transform": out_transform})

        # Save the clipped image as a GeoTIFF
        output_file = f"clipped_{band_name}.tif"
        with rasterio.open(output_file, "w", **out_meta) as dest:
            dest.write(out_image)

        output_files.append(output_file)

# Stack the RGB bands (B02, B03, B04)
rgb_files = [f"clipped_{band_name}.tif" for band_name in ["B02", "B03", "B04"]]
stacked_meta = out_meta.copy()
stacked_meta.update({"count": len(rgb_files)})

stacked_array = None
for rgb_file in rgb_files:
    with rasterio.open(rgb_file) as src:
        band_array = src.read()
        if stacked_array is None:
            stacked_array = band_array
        else:
            stacked_array = np.concatenate((stacked_array, band_array), axis=0)

# Save the stacked RGB array as a GeoTIFF
with rasterio.open("stacked_SR.tif", "w", **stacked_meta) as dest:
    dest.write(stacked_array)
    dest.descriptions = ("blue", "green", "red")

# Plot the stacked RGB image
with rasterio.open("stacked_SR.tif") as src:
    show(src)
# Out:
# ['T35VLD_20230921T094031_B08_10m.jp2', 'T35VLD_20230921T094031_B04_10m.jp2', 'T35VLD_20230921T094031_B03_10m.jp2', 'T35VLD_20230921T094031_B02_10m.jp2']

# %% [markdown]
# To understand the value distribution in our clipped image we can plot the histogram

# %%
# Image histogramm visualisation
with rasterio.open("stacked_SR.tif") as src:
    rasterio.plot.show_hist(src, bins=50, histtype='stepfilled', lw=0.0, stacked=False, alpha=0.3)

# %% [markdown]
# In order to change the visual appearance of the image we can stretch the image

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Stretch each band by standard deviation
def stretch_by_std(band):
    band_mean, band_std = band.mean(), band.std()
    lower_bound = band_mean - 0.5 * band_std
    upper_bound = band_mean + 2 * band_std
    return np.clip((band - lower_bound) / (upper_bound - lower_bound), 0, 1)

# Read bands
blue = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stretch each band by standard deviation
blue_stretched = stretch_by_std(blue)
red_stretched = stretch_by_std(red)
green_stretched = stretch_by_std(green)

# Stack stretched bands
nrg_stretched = np.dstack((blue_stretched, red_stretched, green_stretched))

# View the color composite
plt.imshow(nrg_stretched)
plt.show()

# %% [markdown]
# For further interactive visualisation the geographical bounding box is needed. We will calculate the bounding box from the shape file that we used for clipping

# %%
# Read the shapefile
shapefile_path = '/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp'
gdf = gpd.read_file(shapefile_path)

# Get the bounding box from the GeoDataFrame
bbox = gdf.total_bounds
print(bbox)

#*****************************************************
#Koda sadaļa, ja vektorfaila crs nesakrīt ar rastra crs

# Define the coordinate systems
shapefile_crs = gdf.crs
wgs84_crs = Proj(init='epsg:4326')  # WGS84 CRS

# Transform bounding box to WGS84
lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

#*****************************************************

# Create bounding box in degrees
degree_bbox = [[lon_min, lat_min], [lon_max, lat_max]]

print(degree_bbox)
# Out:
# [495970.00011127 301544.73713625 519750.20311127 326980.43613624]
# [[20.588349183680297, 58.55880806755003], [21.006649164823802, 58.78294868987171]]
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <ipython-input-145-66f3e7f24d82>:17: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
# <ipython-input-145-66f3e7f24d82>:18: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

# %% [markdown]
# By using folium package we can create an interactive map with clipped Sentinel-2 image. Folium does not support Geotiff format so we need to extract the visual information in to .png file and use the geographical coordinates obtained previously to place the image on the map

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Read bands
nir = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stack bands
nrg = np.dstack((nir, red, green))

# Normalize the RGB data
nrg_normalized = nrg / nrg.max()

# Create a folium map
m = folium.Map(location=[56.9483, 24.1057], zoom_start=11)


# Normalize the RGB data
nrg_normalized = (nrg / nrg.max() * 255).astype(np.uint8)

# Apply histogram equalization independently to each channel
nrg_equalized = np.zeros_like(nrg_normalized)
for i in range(3):
    nrg_equalized[:, :, i] = cv2.equalizeHist(nrg_normalized[:, :, i])

# Save the image with transparency
cv2.imwrite('/content/temp_image.png', cv2.cvtColor(nrg_equalized, cv2.COLOR_RGB2BGR))

temp_jpeg_path = '/content/temp_image.png'

# Add the JPEG image as an overlay
folium.raster_layers.ImageOverlay(
    image=temp_jpeg_path,
    bounds= degree_bbox,
    opacity=1,
    name='Sentinel-2 RGB',  # Name for the layer
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)
m

# %% [markdown]
# # Mathematical procedures with spectral images ---> Calculate NDVI
#
# The Normalized Difference Vegetation Index (NDVI) is a widely used vegetation index that quantifies the presence and health of vegetation in remote sensing data, particularly satellite imagery. NDVI is calculated using the near-infrared (NIR) and red (RED) bands of the electromagnetic spectrum.
#
# NDVI is a fundamental tool in understanding the Earth's surface and has become integral in various fields, contributing valuable insights into the dynamics of vegetation and ecosystems.

# %%
#Selecting the channels
b4 = rasterio.open('/content/clipped_B04.tif') # Opening the red channel
b8 = rasterio.open('/content/clipped_B08.tif') # Opening the infra-red channel

red = b4.read(1).astype(float)
nir = b8.read(1).astype(float)

#Check the image stats to see wether we will encounter 0 values for our division || Yes, we will --> our image is partially masked
print("NIR Stats:", np.min(nir), np.max(nir), np.mean(nir))
print("Red Stats:", np.min(red), np.max(red), np.mean(red))

# Add a small constant to the denominator to avoid division by zero
denominator = (nir + red) + 0.0001

# Calculate NDVI, setting NaN for cases where the denominator is zero
ndvi = np.where(denominator == 0, np.nan, (nir - red) / denominator)

# Prepare metadata
meta = b4.meta
meta.update(driver='GTiff')
meta.update(dtype=rasterio.float32, count=1)

# Save NDVI as GeoTIFF
with rasterio.open('NDVI.tif', 'w', **meta) as dst:
    dst.write(ndvi.astype(rasterio.float32), 1)
# Out:
# NIR Stats: 0.0 16576.0 1407.08427734359
# Red Stats: 0.0 17120.0 720.8111870825915

# %% [markdown]
# Plotting the resulting NDVI image

# %%
# Open the NDVI GeoTIFF file
ndvi_file = '/content/NDVI.tif'
with rasterio.open(ndvi_file) as src:
    ndvi = src.read(1)

# Plot the NDVI image and Set the figure size
plt.figure(figsize=(12, 12))
plt.imshow(ndvi, cmap='inferno', extent=[raster.bounds.left, raster.bounds.right, raster.bounds.bottom, raster.bounds.top])
plt.colorbar(label='NDVI')
plt.title('NDVI Image')
plt.show()

# %% [markdown]
# **Extracting the values from generated product**

# %% [markdown]
# We will use rasterstats python library to obtain the statistics of NDVI image

# %%
# Open the NDVI GeoTIFF file
ndvi_file = 'NDVI.tif'
with rasterio.open(ndvi_file) as ndvi_src:
    # Read the shapefile
    aoi_geom = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp')
    aoi_geom = aoi_geom.to_crs(ndvi_src.crs)  # Set the CRS of the shapefile to match the NDVI file

    # Use rasterstats to calculate zonal statistics (mean, median, min, max NDVI)
    stats = zonal_stats(aoi_geom.geometry, ndvi_file, stats=["mean", "median", "min", "max"], nodata=np.nan)

    # Create a GeoDataFrame with the zonal statistics
    gdf_stats = gpd.GeoDataFrame(stats, geometry=aoi_geom.geometry)

    # Extract the statistics values
    mean_ndvi = stats[0]['mean']
    median_ndvi = stats[0]['median']
    min_ndvi = stats[0]['min']
    max_ndvi = stats[0]['max']

# Print the statistics values
print(f"Mean NDVI Value: {mean_ndvi}")
print(f"Median NDVI Value: {median_ndvi}")
print(f"Min NDVI Value: {min_ndvi}")
print(f"Max NDVI Value: {max_ndvi}")
# Out:
# Mean NDVI Value: 0.18868432836219712
# Median NDVI Value: 0.13751116394996643
# Min NDVI Value: -0.09742441028356552
# Max NDVI Value: 0.6658543348312378

# %% [markdown]
# # **Cita Rīgas apkaime**

# %%
url_dataspace = "https://catalogue.dataspace.copernicus.eu/odata/v1"

# Filtering
satellite = "SENTINEL-2"
level = "S2MSI2A"
cloud_cover_max = 0.2

aoi_point ="POINT (23.97509 56.94413)" #The geographic reference for our area of interest

start_date = "2023-06-11"
end_date = "2023-06-12"
start_date_full =start_date+"T00:00:00.000Z"
end_date_full = end_date +"T00:00:00.000Z"

# %%
query = f"{url_dataspace}/Products?$filter=Collection/Name eq '{satellite}' and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'productType' and att/OData.CSC.StringAttribute/Value eq '{level}') and OData.CSC.Intersects(area=geography'SRID=4326;{aoi_point}') and ContentDate/Start gt {start_date_full} and ContentDate/Start lt {end_date_full}"
response = requests.get(query).json()
result = pd.DataFrame.from_dict(response["value"])

# Filter records where 'online' column is True
result = result[result['Online'] == True]

# print first 10 results
result.head(10)
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  e6f0e70b-d23b-48be-89de-b41d00a89373
# 1  application/octet-stream  5a321d45-9422-4cdb-a03a-c3debcfbb52f
#
#                                                 Name  \
# 0  S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_2...
# 1  S2B_MSIL2A_20230611T094549_N0509_R079_T35VLD_2...
#
#                 ContentType  ContentLength                OriginDate  \
# 0  application/octet-stream      974090765  2023-06-11T14:25:50.871Z
# 1  application/octet-stream      710401872  2023-06-11T14:23:30.452Z
#
#             PublicationDate          ModificationDate  Online EvictionDate  \
# 0  2023-06-11T14:32:55.332Z  2023-06-22T21:09:49.057Z    True
# 1  2023-06-11T14:29:16.425Z  2023-06-22T21:07:51.239Z    True
#
#                                               S3Path  \
# 0  /eodata/Sentinel-2/MSI/L2A/2023/06/11/S2B_MSIL...
# 1  /eodata/Sentinel-2/MSI/L2A/2023/06/11/S2B_MSIL...
#
#                                             Checksum  \
# 0  [{'Value': '491840da5f1dfe287fd0bbbec11555db',...
# 1  [{'Value': 'b3acad20c40debbebdd1c3e575cdc958',...
#
#                                          ContentDate  \
# 0  {'Start': '2023-06-11T09:45:49.024Z', 'End': '...
# 1  {'Start': '2023-06-11T09:45:49.024Z', 'End': '...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((22.6793206704832...
# 1  geography'SRID=4326;POLYGON ((25.2334832849166...
#
#                                         GeoFootprint
# 0  {'type': 'Polygon', 'coordinates': [[[22.67932...
# 1  {'type': 'Polygon', 'coordinates': [[[25.23348...

# %%
#Login info
username = ''
password = ''


auth_server_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
data = {
    "client_id": "cdse-public",
    "grant_type": "password",
    "username": username,
    "password": password,
}

response = requests.post(auth_server_url, data=data, verify=True, allow_redirects=False)
access_token = json.loads(response.text)["access_token"]
# Establish session
session = requests.Session()
session.headers["Authorization"] = f"Bearer {access_token}"

product_row_id = 0   # 0 for the first product in the list
product_id = result.iloc[product_row_id, 1]
print(product_id)
product_name = result.iloc[product_row_id, 2]
print(product_name)

url_MTD = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes(MTD_MSIL2A.xml)/$value"
response = session.get(url_MTD, allow_redirects=False)
while response.status_code in (301, 302, 303, 307):
    url_MTD_location = response.headers["Location"]
    response = session.get(url_MTD_location, allow_redirects=False)

file = session.get(url_MTD_location, verify=False, allow_redirects=True)

# Save the product in home directory
outfile = Path("/content/MTD_MSIL2A.xml")
outfile.write_bytes(file.content)
# Out:
# e6f0e70b-d23b-48be-89de-b41d00a89373
# S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE
# 54712

# %%
# Pass the path of the xml document
tree = ET.parse(str(outfile))
# get the parent tag
root = tree.getroot()

# Get the location of individual bands in Sentinel-2 granule
band_path = []
band_path.append(f"{product_name}/{root[0][0][12][0][0][0].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][1].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][2].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][3].text}.jp2".split("/"))

# %%
band_path
# Out:
# [['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B02_10m.jp2'],
#  ['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B03_10m.jp2'],
#  ['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B04_10m.jp2'],
#  ['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B08_10m.jp2']]

# %%
# Build the url
for band_node in band_path:
    url_full = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes({band_node[1]})/Nodes({band_node[2]})/Nodes({band_node[3]})/Nodes({band_node[4]})/Nodes({band_node[5]})/$value"
    #print(url_full)
    response = session.get(url_full, allow_redirects=False)
    while response.status_code in (301, 302, 303, 307):
        url_full_location = response.headers["Location"]
        response = session.get(url_full_location, allow_redirects=False)
    file = session.get(url_full_location, verify=False, allow_redirects=True)
    # Save the product
    outfile =Path("/content/"+band_node[5])
    outfile.write_bytes(file.content)
    print("Saved:", band_node[5])
# Out:
# Saved: T34VFJ_20230611T094549_B02_10m.jp2
# Saved: T34VFJ_20230611T094549_B03_10m.jp2
# Saved: T34VFJ_20230611T094549_B04_10m.jp2
# Saved: T34VFJ_20230611T094549_B08_10m.jp2

# %%
# Read the shapefile
aoi_geom = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp')

# Get a list of input files
input_files = glob.glob('T35VLD_*_B0[2-8]_10m.jp2')
input_files = sorted(input_files, reverse=True)
print(input_files)

# Read the CRS from one of the input files
with rasterio.open(input_files[0]) as src:
    input_crs = src.crs

# Convert the AOI polygon to the input CRS
aoi_geom = aoi_geom.to_crs(input_crs)

band_mapping = {
    "B02": "blue",
    "B03": "green",
    "B04": "red",
    "B08": "infra-red",
}

# Clip and save each band individually
output_files = []
for i, input_file in enumerate(input_files):
    band_name = input_file.split('_')[-2].split('.')[0]
    with rasterio.open(input_file) as src:
        # Clip the image
        out_image, out_transform = mask(src, aoi_geom.geometry, crop=True)

        # Update the metadata
        out_meta = src.meta.copy()
        out_meta.update({"driver": "GTiff",
                         "height": out_image.shape[1],
                         "width": out_image.shape[2],
                         "transform": out_transform})

        # Save the clipped image as a GeoTIFF
        output_file = f"clipped_{band_name}.tif"
        with rasterio.open(output_file, "w", **out_meta) as dest:
            dest.write(out_image)

        output_files.append(output_file)

# Stack the RGB bands (B02, B03, B04)
rgb_files = [f"clipped_{band_name}.tif" for band_name in ["B02", "B03", "B04"]]
stacked_meta = out_meta.copy()
stacked_meta.update({"count": len(rgb_files)})

stacked_array = None
for rgb_file in rgb_files:
    with rasterio.open(rgb_file) as src:
        band_array = src.read()
        if stacked_array is None:
            stacked_array = band_array
        else:
            stacked_array = np.concatenate((stacked_array, band_array), axis=0)

# Save the stacked RGB array as a GeoTIFF
with rasterio.open("stacked_SR.tif", "w", **stacked_meta) as dest:
    dest.write(stacked_array)
    dest.descriptions = ("blue", "green", "red")

# Plot the stacked RGB image
with rasterio.open("stacked_SR.tif") as src:
    show(src)
# Out:
# ['T35VLD_20230921T094031_B08_10m.jp2', 'T35VLD_20230921T094031_B04_10m.jp2', 'T35VLD_20230921T094031_B03_10m.jp2', 'T35VLD_20230921T094031_B02_10m.jp2']

# %%
# Image histogramm visualisation
with rasterio.open("stacked_SR.tif") as src:
    rasterio.plot.show_hist(src, bins=50, histtype='stepfilled', lw=0.0, stacked=False, alpha=0.3)

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Stretch each band by standard deviation
def stretch_by_std(band):
    band_mean, band_std = band.mean(), band.std()
    lower_bound = band_mean - 0.5 * band_std
    upper_bound = band_mean + 2 * band_std
    return np.clip((band - lower_bound) / (upper_bound - lower_bound), 0, 1)

# Read bands
blue = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stretch each band by standard deviation
blue_stretched = stretch_by_std(blue)
red_stretched = stretch_by_std(red)
green_stretched = stretch_by_std(green)

# Stack stretched bands
nrg_stretched = np.dstack((blue_stretched, red_stretched, green_stretched))

# View the color composite
plt.imshow(nrg_stretched)
plt.show()

# %%
# Read the shapefile
shapefile_path = '/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp'
gdf = gpd.read_file(shapefile_path)

# Get the bounding box from the GeoDataFrame
bbox = gdf.total_bounds
print(bbox)

#*****************************************************
#Koda sadaļa, ja vektorfaila crs nesakrīt ar rastra crs

# Define the coordinate systems
shapefile_crs = gdf.crs
wgs84_crs = Proj(init='epsg:4326')  # WGS84 CRS

# Transform bounding box to WGS84
lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

#*****************************************************

# Create bounding box in degrees
degree_bbox = [[lon_min, lat_min], [lon_max, lat_max]]

print(degree_bbox)
# Out:
# [495970.00011127 301544.73713625 519750.20311127 326980.43613624]
# [[20.588349183680297, 58.55880806755003], [21.006649164823802, 58.78294868987171]]
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <ipython-input-159-66f3e7f24d82>:17: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
# <ipython-input-159-66f3e7f24d82>:18: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Read bands
nir = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stack bands
nrg = np.dstack((nir, red, green))

# Normalize the RGB data
nrg_normalized = nrg / nrg.max()

# Create a folium map
m = folium.Map(location=[56.94413, 23.97509], zoom_start=11)


# Normalize the RGB data
nrg_normalized = (nrg / nrg.max() * 255).astype(np.uint8)

# Apply histogram equalization independently to each channel
nrg_equalized = np.zeros_like(nrg_normalized)
for i in range(3):
    nrg_equalized[:, :, i] = cv2.equalizeHist(nrg_normalized[:, :, i])

# Save the image with transparency
cv2.imwrite('/content/temp_image.png', cv2.cvtColor(nrg_equalized, cv2.COLOR_RGB2BGR))

temp_jpeg_path = '/content/temp_image.png'

# Add the JPEG image as an overlay
folium.raster_layers.ImageOverlay(
    image=temp_jpeg_path,
    bounds= degree_bbox,
    opacity=1,
    name='Sentinel-2 RGB',  # Name for the layer
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)
m

# %%
# Selecting the channels
b4 = rasterio.open('/content/clipped_B04.tif')  # Opening the red channel
b8 = rasterio.open('/content/clipped_B08.tif')  # Opening the infra-red channel

red = b4.read(1).astype(float)
nir = b8.read(1).astype(float)

# Check the image stats to see whether we will encounter 0 values for our division || Yes, we will --> our image is partially masked
print("NIR Stats:", np.min(nir), np.max(nir), np.mean(nir))
print("Red Stats:", np.min(red), np.max(red), np.mean(red))

# Set NaN for cases where the denominator is zero
denominator = np.where(nir + red == 0, np.nan, nir + red)

# Calculate NDVI
ndvi = np.where(denominator == 0, np.nan, (nir - red) / denominator)

# Prepare metadata
meta = b4.meta
meta.update(driver='GTiff')
meta.update(dtype=rasterio.float32, count=1)

# Save NDVI as GeoTIFF
with rasterio.open('NDVI.tif', 'w', **meta) as dst:
  dst.write(ndvi.astype(rasterio.float32), 1)
# Out:
# NIR Stats: 0.0 16576.0 1407.08427734359
# Red Stats: 0.0 17120.0 720.8111870825915

# %%
# Open the NDVI GeoTIFF file
ndvi_file = '/content/NDVI.tif'
with rasterio.open(ndvi_file) as src:
  ndvi = src.read(1)

# Plot the NDVI image and Set the figure size
plt.figure(figsize=(12, 12))
plt.imshow(ndvi, cmap='inferno', extent=[raster.bounds.left, raster.bounds.right, raster.bounds.bottom, raster.bounds.top])
plt.colorbar(label='NDVI')
plt.title('NDVI Image')
plt.show()

# %%
# Print and visualize AOI
print(aoi_geom)
aoi_geom.plot()
plt.show()
# Out:
#                ELEM_TEXT                                           geometry
# 0          Sarkandaugava  POLYGON ((325696.177 6322704.360, 325697.229 6...
# 1          Ziepniekkalns  POLYGON ((324967.289 6311892.165, 324910.700 6...
# 2           Vecmilgrāvis  POLYGON ((322937.269 6326709.100, 323548.940 6...
# 3            Daugavgrīva  POLYGON ((321501.975 6326508.742, 321666.531 6...
# 4            Kundziņsala  POLYGON ((324704.326 6323761.488, 324766.180 6...
# 5            Čiekurkalns  POLYGON ((329845.553 6321398.137, 329910.244 6...
# 6              Bišumuiža  POLYGON ((325861.854 6311798.611, 325861.380 6...
# 7             Torņakalns  POLYGON ((323826.786 6314741.723, 323762.761 6...
# 8             Āgenskalns  POLYGON ((322422.724 6315470.564, 322552.043 6...
# 9              Dzirciems  POLYGON ((322422.724 6315470.564, 322401.341 6...
# 10            Mangaļsala  POLYGON ((323734.634 6328606.281, 323619.376 6...
# 11            Vecpilsēta  POLYGON ((324544.465 6315113.575, 324191.967 6...
# 12                Centrs  POLYGON ((325943.085 6316919.190, 326155.751 6...
# 13            Šampēteris  POLYGON ((319688.745 6315414.799, 320098.920 6...
# 14            Pleskodāle  POLYGON ((320741.337 6314513.073, 321194.292 6...
# 15             Mūkupurvs  POLYGON ((316488.244 6315869.477, 316585.019 6...
# 16             Beberbeķi  POLYGON ((316615.159 6315989.905, 316605.418 6...
# 17             Iļģuciems  POLYGON ((322367.147 6317639.424, 322329.301 6...
# 18             Bolderāja  POLYGON ((321798.428 6325594.913, 321828.130 6...
# 19                 Buļļi  POLYGON ((318126.303 6323645.720, 318048.089 6...
# 20             Trīsciems  POLYGON ((327871.404 6327040.303, 327820.164 6...
# 21             Jaunciems  POLYGON ((329928.764 6323714.989, 329780.922 6...
# 22             Mežaparks  POLYGON ((329257.463 6321571.400, 328962.970 6...
# 23             Purvciems  POLYGON ((330272.588 6315733.485, 330273.802 6...
# 24             Pļavnieki  POLYGON ((330118.362 6314882.683, 330386.929 6...
# 25             Dārzciems  POLYGON ((329469.793 6315070.130, 329454.279 6...
# 26             Ķengarags  POLYGON ((330551.719 6309874.276, 330535.579 6...
# 27             Šķirotava  POLYGON ((331169.666 6309300.009, 330972.690 6...
# 28              Mežciems  POLYGON ((333226.883 6315894.135, 333226.767 6...
# 29              Dreiliņi  POLYGON ((333226.883 6315894.135, 333226.792 6...
# 30     Maskavas forštate  POLYGON ((325173.747 6315118.868, 325927.005 6...
# 31              Zolitūde  POLYGON ((319143.495 6315598.712, 319112.959 6...
# 32               Ķīpsala  POLYGON ((322973.463 6317846.635, 322943.799 6...
# 33               Bukulti  POLYGON ((334992.598 6320908.446, 334909.281 6...
# 34               Rumbula  POLYGON ((330551.719 6309874.276, 330972.690 6...
# 35               Dārziņi  POLYGON ((331707.482 6306404.093, 331711.340 6...
# 36               Bieriņi  POLYGON ((322255.953 6313002.590, 322256.747 6...
# 37                Imanta  POLYGON ((320482.496 6318445.912, 320480.458 6...
# 38                Spilve  POLYGON ((321839.340 6322892.429, 321918.687 6...
# 39                Voleri  POLYGON ((323006.333 6324510.183, 323009.874 6...
# 40                Vecāķi  POLYGON ((325573.458 6329694.639, 325332.399 6...
# 41                 Jugla  POLYGON ((330671.626 6321336.406, 330952.689 6...
# 42                 Teika  POLYGON ((330464.971 6318893.998, 330423.066 6...
# 43                  Suži  POLYGON ((332278.309 6322270.929, 332152.446 6...
# 44               Kleisti  POLYGON ((320866.278 6322673.349, 320768.528 6...
# 45             Mīlgrāvis  POLYGON ((327892.994 6324200.376, 327688.363 6...
# 46               Skanste  POLYGON ((325475.937 6317767.707, 325474.997 6...
# 47  Pētersala-Andrejsala  POLYGON ((324591.743 6318541.932, 324501.898 6...
# 48                 Brasa  POLYGON ((326432.875 6318767.113, 326471.389 6...
# 49           Grīziņkalns  POLYGON ((327121.168 6317076.321, 327168.459 6...
# 50                 Avoti  POLYGON ((327319.248 6315689.446, 327307.869 6...
# 51                 Berģi  POLYGON ((336887.485 6317651.637, 336842.777 6...
# 52                Brekši  POLYGON ((336887.485 6317651.637, 336886.640 6...
# 53             Zasulauks  POLYGON ((320330.561 6315901.921, 320390.990 6...
# 54            Katlakalns  POLYGON ((326916.173 6311666.465, 327648.534 6...
# 55              Atgāzene  POLYGON ((322755.665 6312090.651, 322568.615 6...
# 56            Vecdaugava  POLYGON ((324549.085 6328033.541, 324554.414 6...
# 57                 Salas  POLYGON ((323826.786 6314741.723, 323879.168 6...

# %%
# Print zonal statistics
print(stats)
# Out:
# [{'min': -0.09742441028356552, 'max': 0.6658543348312378, 'mean': 0.18868432836219712, 'median': 0.13751116394996643}, {'min': -0.12882153689861298, 'max': 0.7020284533500671, 'mean': 0.33932965687956307, 'median': 0.37319111824035645}, {'min': -0.21307188272476196, 'max': 0.6592749953269958, 'mean': 0.17865304809885202, 'median': 0.13251833617687225}, {'min': -0.1899031400680542, 'max': 0.737658679485321, 'mean': 0.2560894372123795, 'median': 0.2913198471069336}, {'min': -0.11357506364583969, 'max': 0.6911038756370544, 'mean': 0.19315000877500876, 'median': 0.16073206067085266}, {'min': -0.16024340689182281, 'max': 0.6831910014152527, 'mean': 0.2510917498159221, 'median': 0.2540026307106018}, {'min': -0.025355251505970955, 'max': 0.6901123523712158, 'mean': 0.3912709719727565, 'median': 0.41434261202812195}, {'min': -0.1879093199968338, 'max': 0.6815606951713562, 'mean': 0.24480850867276593, 'median': 0.23331747949123383}, {'min': -0.05964503809809685, 'max': 0.689984917640686, 'mean': 0.27389416408842926, 'median': 0.28057554364204407}, {'min': -0.156356543302536, 'max': 0.7098751068115234, 'mean': 0.3091962634687244, 'median': 0.3247602581977844}, {'min': -0.10569105297327042, 'max': 0.6519306302070618, 'mean': 0.28100200283285265, 'median': 0.3611111044883728}, {'min': -0.10940032452344894, 'max': 0.5999999642372131, 'mean': 0.048677563917842316, 'median': 0.013973170891404152}, {'min': -0.11699163913726807, 'max': 0.6155010461807251, 'mean': 0.13699566473564842, 'median': 0.07256392389535904}, {'min': -0.04936760291457176, 'max': 0.6696298122406006, 'mean': 0.27273490395937594, 'median': 0.27903997898101807}, {'min': -0.08072653412818909, 'max': 0.6576194763183594, 'mean': 0.32352278440103416, 'median': 0.3549175262451172}, {'min': -0.008387697860598564, 'max': 0.6726342439651489, 'mean': 0.4315057630820375, 'median': 0.4367087185382843}, {'min': -0.010067113675177097, 'max': 0.6767833828926086, 'mean': 0.4086458744187495, 'median': 0.42884430289268494}, {'min': -0.07361268252134323, 'max': 0.7172726392745972, 'mean': 0.2793245048852516, 'median': 0.2868020236492157}, {'min': -0.07145586609840393, 'max': 0.6627577543258667, 'mean': 0.29802053202803436, 'median': 0.3393622636795044}, {'min': -0.1306256800889969, 'max': 0.6607457399368286, 'mean': 0.3480842451849811, 'median': 0.39629805088043213}, {'min': -0.06554081290960312, 'max': 0.7136472463607788, 'mean': 0.30302424829321273, 'median': 0.3641674816608429}, {'min': -0.05857914313673973, 'max': 0.681174099445343, 'mean': 0.1750048649692632, 'median': 0.0433000847697258}, {'min': -0.08265802264213562, 'max': 0.6958437561988831, 'mean': 0.30568875576714793, 'median': 0.39008620381355286}, {'min': -0.06499608606100082, 'max': 0.6736655831336975, 'mean': 0.2776011356980859, 'median': 0.27406764030456543}, {'min': -0.03883875906467438, 'max': 0.6976152062416077, 'mean': 0.2887959620550705, 'median': 0.2926143407821655}, {'min': -0.6282308101654053, 'max': 0.7605421543121338, 'mean': 0.27271293434658095, 'median': 0.2752111554145813}, {'min': -0.061018019914627075, 'max': 0.6894944310188293, 'mean': 0.22831510681130124, 'median': 0.22962962090969086}, {'min': -0.07520091533660889, 'max': 0.6692165732383728, 'mean': 0.30763921566547175, 'median': 0.3630504608154297}, {'min': -0.16999998688697815, 'max': 0.6871992349624634, 'mean': 0.3678664233172604, 'median': 0.39730289578437805}, {'min': -0.33565521240234375, 'max': 0.7052029371261597, 'mean': 0.34508787820783204, 'median': 0.3836868703365326}, {'min': -0.1369047611951828, 'max': 0.698573887348175, 'mean': 0.18310076158565977, 'median': 0.12830641865730286}, {'min': -0.0716845840215683, 'max': 0.6736146211624146, 'mean': 0.33764096654920467, 'median': 0.35704874992370605}, {'min': -0.07727532833814621, 'max': 0.6736092567443848, 'mean': 0.1635372595849577, 'median': 0.06625766307115555}, {'min': -0.16817723214626312, 'max': 0.7040358781814575, 'mean': 0.3402375224558872, 'median': 0.3944048285484314}, {'min': -0.10376188158 ...

# %%
stats_df = pd.DataFrame(stats)
# Save the DataFrame to a CSV file
# stats_df.to_csv('/content/stats.csv', index=False)

# %%
display(stats_df)
# Out:
#          min       max      mean    median
# 0  -0.097424  0.665854  0.188684  0.137511
# 1  -0.128822  0.702028  0.339330  0.373191
# 2  -0.213072  0.659275  0.178653  0.132518
# 3  -0.189903  0.737659  0.256089  0.291320
# 4  -0.113575  0.691104  0.193150  0.160732
# 5  -0.160243  0.683191  0.251092  0.254003
# 6  -0.025355  0.690112  0.391271  0.414343
# 7  -0.187909  0.681561  0.244809  0.233317
# 8  -0.059645  0.689985  0.273894  0.280576
# 9  -0.156357  0.709875  0.309196  0.324760
# 10 -0.105691  0.651931  0.281002  0.361111
# 11 -0.109400  0.600000  0.048678  0.013973
# 12 -0.116992  0.615501  0.136996  0.072564
# 13 -0.049368  0.669630  0.272735  0.279040
# 14 -0.080727  0.657619  0.323523  0.354918
# 15 -0.008388  0.672634  0.431506  0.436709
# 16 -0.010067  0.676783  0.408646  0.428844
# 17 -0.073613  0.717273  0.279325  0.286802
# 18 -0.071456  0.662758  0.298021  0.339362
# 19 -0.130626  0.660746  0.348084  0.396298
# 20 -0.065541  0.713647  0.303024  0.364167
# 21 -0.058579  0.681174  0.175005  0.043300
# 22 -0.082658  0.695844  0.305689  0.390086
# 23 -0.064996  0.673666  0.277601  0.274068
# 24 -0.038839  0.697615  0.288796  0.292614
# 25 -0.628231  0.760542  0.272713  0.275211
# 26 -0.061018  0.689494  0.228315  0.229630
# 27 -0.075201  0.669217  0.307639  0.363050
# 28 -0.170000  0.687199  0.367866  0.397303
# 29 -0.335655  0.705203  0.345088  0.383687
# 30 -0.136905  0.698574  0.183101  0.128306
# 31 -0.071685  0.673615  0.337641  0.357049
# 32 -0.077275  0.673609  0.163537  0.066258
# 33 -0.168177  0.704036  0.340238  0.394405
# 34 -0.103762  0.683347  0.288598  0.336245
# 35 -0.062706  0.705243  0.339470  0.386001
# 36 -0.053392  0.679643  0.378383  0.392161
# 37 -0.145848  0.688388  0.328947  0.365130
# 38 -0.075889  0.684159  0.405544  0.448657
# 39 -0.109234  0.676860  0.220021  0.170623
# 40 -0.042778  0.647189  0.337516  0.371375
# 41 -0.054379  0.707074  0.306536  0.380159
# 42 -0.078822  0.674133  0.241544  0.240004
# 43 -0.090663  0.660878  0.214945  0.257501
# 44 -0.062822  0.694360  0.413401  0.418035
# 45 -0.087045  0.687316  0.214812  0.179676
# 46 -0.070453  0.669065  0.266472  0.255798
# 47 -0.068001  0.668381  0.153707  0.086885
# 48 -0.102797  0.666492  0.271283  0.261475
# 49 -0.137884  0.629877  0.183254  0.141370
# 50 -0.546889  0.643910  0.170327  0.128259
# 51 -0.053763  0.674369  0.205254  0.243697
# 52 -0.049057  0.667479  0.315913  0.354416
# 53 -0.037142  0.676697  0.329193  0.347541
# 54 -0.086920  0.646364  0.149939  0.058106
# 55 -0.017003  0.671264  0.350424  0.378481
# 56 -0.048598  0.680715  0.325440  0.352638
# 57 -0.058144  0.686481  0.276700  0.355695

# %%
max_ndvi_row = stats_df.loc[stats_df['mean'].idxmax()]
display(max_ndvi_row)
# Out:
# min      -0.008388
# max       0.672634
# mean      0.431506
# median    0.436709
# Name: 15, dtype: float64

# %% [markdown]
# ## Pats lielākais biomasas apjoms ir Mūkupurva apkaimē.

# %% [markdown]
# # 5.2
#
# Atkārtot uzdevumu 5.1, novērtējot biomasu 500 metru radiusā no Jūsu dzīves vietas. Reģions (shape) būs aplis vai poligons, kas iekļauj +- 500 metrus no Jūsu dzīves vietas jebkurā virzienā. Variet arī paplašināt analizējamo reģionu, palielinot radiusu.

# %%
import os
import re
import sys
import glob
from pathlib import Path

import requests
import json
import xml.etree.ElementTree as ET
import certifi

import pandas as pd
import numpy as np
import rasterio
from rasterio.mask import mask
from rasterio.plot import show
from rasterio.windows import Window
import matplotlib.pyplot as plt
import matplotlib.image
import folium
import cv2
import geopandas as gpd
from rasterstats import zonal_stats
from pyproj import Proj, transform
import shapely.geometry
from shapely.geometry import Polygon
from geopandas import GeoDataFrame

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url_dataspace = "https://catalogue.dataspace.copernicus.eu/odata/v1"

# Filtering
satellite = "SENTINEL-2"
level = "S2MSI2A"
cloud_cover_max = 0.2

rectangle_coordinates = [
    (24.14705, 56.96255),
    (24.13765, 56.95780),
    (24.13001, 56.96192),
    (24.13988, 56.96643),
]

# Create a Shapely polygon from the coordinates
aoi_polygon = shapely.geometry.Polygon(rectangle_coordinates)

# Convert the polygon to WKT (Well-Known Text) format for the query
aoi_wkt = aoi_polygon.wkt

start_date = "2023-06-11"
end_date = "2023-06-12"
start_date_full =start_date+"T00:00:00.000Z"
end_date_full = end_date +"T00:00:00.000Z"

# %%
query = f"{url_dataspace}/Products?$filter=Collection/Name eq '{satellite}' and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'productType' and att/OData.CSC.StringAttribute/Value eq '{level}') and OData.CSC.Intersects(area=geography'SRID=4326;{aoi_wkt}') and ContentDate/Start gt {start_date_full} and ContentDate/Start lt {end_date_full}"
response = requests.get(query).json()
result = pd.DataFrame.from_dict(response["value"])

# Filter records where 'online' column is True
result = result[result['Online'] == True]

# print first 10 results
result.head(10)
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  e6f0e70b-d23b-48be-89de-b41d00a89373
# 1  application/octet-stream  5a321d45-9422-4cdb-a03a-c3debcfbb52f
#
#                                                 Name  \
# 0  S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_2...
# 1  S2B_MSIL2A_20230611T094549_N0509_R079_T35VLD_2...
#
#                 ContentType  ContentLength                OriginDate  \
# 0  application/octet-stream      974090765  2023-06-11T14:25:50.871Z
# 1  application/octet-stream      710401872  2023-06-11T14:23:30.452Z
#
#             PublicationDate          ModificationDate  Online EvictionDate  \
# 0  2023-06-11T14:32:55.332Z  2023-06-22T21:09:49.057Z    True
# 1  2023-06-11T14:29:16.425Z  2023-06-22T21:07:51.239Z    True
#
#                                               S3Path  \
# 0  /eodata/Sentinel-2/MSI/L2A/2023/06/11/S2B_MSIL...
# 1  /eodata/Sentinel-2/MSI/L2A/2023/06/11/S2B_MSIL...
#
#                                             Checksum  \
# 0  [{'Value': '491840da5f1dfe287fd0bbbec11555db',...
# 1  [{'Value': 'b3acad20c40debbebdd1c3e575cdc958',...
#
#                                          ContentDate  \
# 0  {'Start': '2023-06-11T09:45:49.024Z', 'End': '...
# 1  {'Start': '2023-06-11T09:45:49.024Z', 'End': '...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((22.6793206704832...
# 1  geography'SRID=4326;POLYGON ((25.2334832849166...
#
#                                         GeoFootprint
# 0  {'type': 'Polygon', 'coordinates': [[[22.67932...
# 1  {'type': 'Polygon', 'coordinates': [[[25.23348...

# %%
#Login info
username = ''
password = ''


auth_server_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
data = {
    "client_id": "cdse-public",
    "grant_type": "password",
    "username": username,
    "password": password,
}

response = requests.post(auth_server_url, data=data, verify=True, allow_redirects=False)
access_token = json.loads(response.text)["access_token"]
# Establish session
session = requests.Session()
session.headers["Authorization"] = f"Bearer {access_token}"

product_row_id = 0   # 0 for the first product in the list
product_id = result.iloc[product_row_id, 1]
print(product_id)
product_name = result.iloc[product_row_id, 2]
print(product_name)

url_MTD = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes(MTD_MSIL2A.xml)/$value"
response = session.get(url_MTD, allow_redirects=False)
while response.status_code in (301, 302, 303, 307):
    url_MTD_location = response.headers["Location"]
    response = session.get(url_MTD_location, allow_redirects=False)

file = session.get(url_MTD_location, verify=False, allow_redirects=True)

# Save the product in home directory
outfile = Path("/content/MTD_MSIL2A.xml")
outfile.write_bytes(file.content)
# Out:
# e6f0e70b-d23b-48be-89de-b41d00a89373
# S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE
# 54712

# %%
# Pass the path of the xml document
tree = ET.parse(str(outfile))
# get the parent tag
root = tree.getroot()

# Get the location of individual bands in Sentinel-2 granule
band_path = []
band_path.append(f"{product_name}/{root[0][0][12][0][0][0].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][1].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][2].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][3].text}.jp2".split("/"))

# %%
band_path
# Out:
# [['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B02_10m.jp2'],
#  ['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B03_10m.jp2'],
#  ['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B04_10m.jp2'],
#  ['S2B_MSIL2A_20230611T094549_N0509_R079_T34VFJ_20230611T113435.SAFE',
#   'GRANULE',
#   'L2A_T34VFJ_A032709_20230611T094803',
#   'IMG_DATA',
#   'R10m',
#   'T34VFJ_20230611T094549_B08_10m.jp2']]

# %%
# Build the url
for band_node in band_path:
    url_full = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes({band_node[1]})/Nodes({band_node[2]})/Nodes({band_node[3]})/Nodes({band_node[4]})/Nodes({band_node[5]})/$value"
    #print(url_full)
    response = session.get(url_full, allow_redirects=False)
    while response.status_code in (301, 302, 303, 307):
        url_full_location = response.headers["Location"]
        response = session.get(url_full_location, allow_redirects=False)
    file = session.get(url_full_location, verify=False, allow_redirects=True)
    # Save the product
    outfile =Path("/content/"+band_node[5])
    outfile.write_bytes(file.content)
    print("Saved:", band_node[5])
# Out:
# Saved: T34VFJ_20230611T094549_B02_10m.jp2
# Saved: T34VFJ_20230611T094549_B03_10m.jp2
# Saved: T34VFJ_20230611T094549_B04_10m.jp2
# Saved: T34VFJ_20230611T094549_B08_10m.jp2

# %%
# Read the shapefile
aoi_geom = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp')

# Get a list of input files
input_files = glob.glob('T35VLD_*_B0[2-8]_10m.jp2')
input_files = sorted(input_files, reverse=True)
print(input_files)

# Read the CRS from one of the input files
with rasterio.open(input_files[0]) as src:
    input_crs = src.crs

# Convert the AOI polygon to the input CRS
aoi_geom = aoi_geom.to_crs(input_crs)

band_mapping = {
    "B02": "blue",
    "B03": "green",
    "B04": "red",
    "B08": "infra-red",
}

# Clip and save each band individually
output_files = []
for i, input_file in enumerate(input_files):
    band_name = input_file.split('_')[-2].split('.')[0]
    with rasterio.open(input_file) as src:
        # Clip the image
        out_image, out_transform = mask(src, aoi_geom.geometry, crop=True)

        # Update the metadata
        out_meta = src.meta.copy()
        out_meta.update({"driver": "GTiff",
                         "height": out_image.shape[1],
                         "width": out_image.shape[2],
                         "transform": out_transform})

        # Save the clipped image as a GeoTIFF
        output_file = f"clipped_{band_name}.tif"
        with rasterio.open(output_file, "w", **out_meta) as dest:
            dest.write(out_image)

        output_files.append(output_file)

# Stack the RGB bands (B02, B03, B04)
rgb_files = [f"clipped_{band_name}.tif" for band_name in ["B02", "B03", "B04"]]
stacked_meta = out_meta.copy()
stacked_meta.update({"count": len(rgb_files)})

stacked_array = None
for rgb_file in rgb_files:
    with rasterio.open(rgb_file) as src:
        band_array = src.read()
        if stacked_array is None:
            stacked_array = band_array
        else:
            stacked_array = np.concatenate((stacked_array, band_array), axis=0)

# Save the stacked RGB array as a GeoTIFF
with rasterio.open("stacked_SR.tif", "w", **stacked_meta) as dest:
    dest.write(stacked_array)
    dest.descriptions = ("blue", "green", "red")

# Plot the stacked RGB image
with rasterio.open("stacked_SR.tif") as src:
    show(src)
# Out:
# ['T35VLD_20230921T094031_B08_10m.jp2', 'T35VLD_20230921T094031_B04_10m.jp2', 'T35VLD_20230921T094031_B03_10m.jp2', 'T35VLD_20230921T094031_B02_10m.jp2']

# %%
# Image histogramm visualisation
with rasterio.open("stacked_SR.tif") as src:
    rasterio.plot.show_hist(src, bins=50, histtype='stepfilled', lw=0.0, stacked=False, alpha=0.3)

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Stretch each band by standard deviation
def stretch_by_std(band):
    band_mean, band_std = band.mean(), band.std()
    lower_bound = band_mean - 0.5 * band_std
    upper_bound = band_mean + 2 * band_std
    return np.clip((band - lower_bound) / (upper_bound - lower_bound), 0, 1)

# Read bands
blue = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stretch each band by standard deviation
blue_stretched = stretch_by_std(blue)
red_stretched = stretch_by_std(red)
green_stretched = stretch_by_std(green)

# Stack stretched bands
nrg_stretched = np.dstack((blue_stretched, red_stretched, green_stretched))

# View the color composite
plt.imshow(nrg_stretched)
plt.show()

# %%
# Read the shapefile
shapefile_path = '/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp'
gdf = gpd.read_file(shapefile_path)

# Get the bounding box from the GeoDataFrame
bbox = gdf.total_bounds
print(bbox)

#*****************************************************
#Koda sadaļa, ja vektorfaila crs nesakrīt ar rastra crs

# Define the coordinate systems
shapefile_crs = gdf.crs
wgs84_crs = Proj(init='epsg:4326')  # WGS84 CRS

# Transform bounding box to WGS84
lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

#*****************************************************

# Create bounding box in degrees
degree_bbox = [[lon_min, lat_min], [lon_max, lat_max]]

print(degree_bbox)
# Out:
# [495970.00011127 301544.73713625 519750.20311127 326980.43613624]
# [[20.588349183680297, 58.55880806755003], [21.006649164823802, 58.78294868987171]]
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <ipython-input-178-66f3e7f24d82>:17: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
# <ipython-input-178-66f3e7f24d82>:18: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Read bands
nir = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stack bands
nrg = np.dstack((nir, red, green))

# Normalize the RGB data
nrg_normalized = nrg / nrg.max()

# Calculate center of the rectangle
center_lat = sum(coord[1] for coord in rectangle_coordinates) / len(rectangle_coordinates)
center_lon = sum(coord[0] for coord in rectangle_coordinates) / len(rectangle_coordinates)

# Create a folium map
m = folium.Map(location=[center_lat, center_lon], zoom_start=11)

# Add a rectangle overlay
folium.Polygon(locations=rectangle_coordinates, color='blue', fill=True, fill_color='blue', fill_opacity=0.2).add_to(m)

# Normalize the RGB data
nrg_normalized = (nrg / nrg.max() * 255).astype(np.uint8)

# Apply histogram equalization independently to each channel
nrg_equalized = np.zeros_like(nrg_normalized)
for i in range(3):
    nrg_equalized[:, :, i] = cv2.equalizeHist(nrg_normalized[:, :, i])

# Save the image with transparency
cv2.imwrite('/content/temp_image.png', cv2.cvtColor(nrg_equalized, cv2.COLOR_RGB2BGR))

temp_jpeg_path = '/content/temp_image.png'

# Add the JPEG image as an overlay
folium.raster_layers.ImageOverlay(
    image=temp_jpeg_path,
    bounds= degree_bbox,
    opacity=1,
    name='Sentinel-2 RGB',  # Name for the layer
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)
m

# %%
# Selecting the channels
b4 = rasterio.open('/content/clipped_B04.tif')  # Opening the red channel
b8 = rasterio.open('/content/clipped_B08.tif')  # Opening the infra-red channel

red = b4.read(1).astype(float)
nir = b8.read(1).astype(float)

# Check the image stats to see whether we will encounter 0 values for our division || Yes, we will --> our image is partially masked
print("NIR Stats:", np.min(nir), np.max(nir), np.mean(nir))
print("Red Stats:", np.min(red), np.max(red), np.mean(red))

# Set NaN for cases where the denominator is zero
denominator = np.where(nir + red == 0, np.nan, nir + red)

# Calculate NDVI
ndvi = np.where(denominator == 0, np.nan, (nir - red) / denominator)

# Prepare metadata
meta = b4.meta
meta.update(driver='GTiff')
meta.update(dtype=rasterio.float32, count=1)

# Save NDVI as GeoTIFF
with rasterio.open('NDVI.tif', 'w', **meta) as dst:
  dst.write(ndvi.astype(rasterio.float32), 1)
# Out:
# NIR Stats: 0.0 16576.0 1407.08427734359
# Red Stats: 0.0 17120.0 720.8111870825915

# %%
# Open the NDVI GeoTIFF file
ndvi_file = '/content/NDVI.tif'
with rasterio.open(ndvi_file) as src:
  ndvi = src.read(1)

# Plot the NDVI image and Set the figure size
plt.figure(figsize=(12, 12))
plt.imshow(ndvi, cmap='inferno', extent=[raster.bounds.left, raster.bounds.right, raster.bounds.bottom, raster.bounds.top])
plt.colorbar(label='NDVI')
plt.title('NDVI Image')
plt.show()

# %%
# Create a GeoDataFrame with the rectangle polygon
rectangle_gdf = GeoDataFrame(geometry=[aoi_polygon])

# Set the CRS for the GeoDataFrame (EPSG:4326 is WGS 84)
rectangle_gdf.crs = "EPSG:4326"

# Print the GeoDataFrame to verify the CRS is set
print(rectangle_gdf)

# Continue with the rest of the code
with rasterio.open(ndvi_file) as ndvi_src:
    # Reproject the GeoDataFrame to match the raster CRS
    rectangle_gdf = rectangle_gdf.to_crs(ndvi_src.crs)

    # Perform zonal statistics
    stats = zonal_stats(rectangle_gdf.geometry, ndvi_file, stats=["mean", "median", "min", "max"], nodata=np.nan)

    # Create a GeoDataFrame with the zonal statistics
    gdf_stats = GeoDataFrame(stats, geometry=rectangle_gdf.geometry)

    # Retrieve statistics values
    mean_ndvi = stats[0]['mean']
    median_ndvi = stats[0]['median']
    min_ndvi = stats[0]['min']
    max_ndvi = stats[0]['max']

print(f"Mean NDVI Value: {mean_ndvi}")
print(f"Median NDVI Value: {median_ndvi}")
print(f"Min NDVI Value: {min_ndvi}")
print(f"Max NDVI Value: {max_ndvi}")
# Out:
#                                             geometry
# 0  POLYGON ((24.14705 56.96255, 24.13765 56.95780...
# Mean NDVI Value: 0.15663705100301603
# Median NDVI Value: 0.1048344224691391
# Min NDVI Value: -0.10279694944620132
# Max NDVI Value: 0.5815714597702026

# %% [markdown]
# # Izmantojot 1 punktu ar rādiusu 500m

# %%
import os
import re
import sys
import glob
from pathlib import Path

import requests
import json
import xml.etree.ElementTree as ET
import certifi

import pandas as pd
import numpy as np
import rasterio
from rasterio.mask import mask
from rasterio.plot import show
from rasterio.windows import Window
import matplotlib.pyplot as plt
import matplotlib.image
import folium
import cv2
import geopandas as gpd
from rasterstats import zonal_stats
from pyproj import Proj, transform
import shapely.geometry

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url_dataspace = "https://catalogue.dataspace.copernicus.eu/odata/v1"

# Filtering
satellite = "SENTINEL-2"
level = "S2MSI2A"
cloud_cover_max = 0.2

# Specify the coordinates of the point
point_coordinates = (24.13814, 56.96239)

# Create a Shapely point
aoi_point = shapely.geometry.Point(point_coordinates)

# Create a circular buffer around the point with a radius of 500 meters
buffer_radius = 0.0045  # Approximately 500 meters in degrees (adjust as needed)
aoi_circle = aoi_point.buffer(buffer_radius)

# Convert the circle to WKT (Well-Known Text) format for the query
aoi_wkt = aoi_circle.wkt

start_date = "2023-09-21"
end_date = "2023-09-22"
start_date_full = start_date + "T00:00:00.000Z"
end_date_full = end_date + "T00:00:00.000Z"

# %%
query = f"{url_dataspace}/Products?$filter=Collection/Name eq '{satellite}' and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'productType' and att/OData.CSC.StringAttribute/Value eq '{level}') and OData.CSC.Intersects(area=geography'SRID=4326;{aoi_wkt}') and ContentDate/Start gt {start_date_full} and ContentDate/Start lt {end_date_full}"
response = requests.get(query).json()
result = pd.DataFrame.from_dict(response["value"])

# Filter records where 'online' column is True
result = result[result['Online'] == True]

# print first 10 results
result.head(10)
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  1de62670-72bc-42dc-9e42-1c0c7c5d8ba9
# 1  application/octet-stream  25708026-43f7-45e0-9a16-37fda7a2df1f
#
#                                                 Name  \
# 0  S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_2...
# 1  S2A_MSIL2A_20230921T094031_N0509_R036_T34VFJ_2...
#
#                 ContentType  ContentLength                OriginDate  \
# 0  application/octet-stream     1103539805  2023-09-21T17:21:00.553Z
# 1  application/octet-stream      983725792  2023-09-21T17:16:30.386Z
#
#             PublicationDate          ModificationDate  Online EvictionDate  \
# 0  2023-09-21T17:27:50.618Z  2023-09-21T17:28:11.021Z    True
# 1  2023-09-21T17:27:30.796Z  2023-09-21T17:27:45.705Z    True
#
#                                               S3Path  \
# 0  /eodata/Sentinel-2/MSI/L2A/2023/09/21/S2A_MSIL...
# 1  /eodata/Sentinel-2/MSI/L2A/2023/09/21/S2A_MSIL...
#
#                                             Checksum  \
# 0  [{'Value': '5604fae0921e3564bfd27e42b6953dd4',...
# 1  [{'Value': 'ace53df9e562f9100afdc89581a48761',...
#
#                                          ContentDate  \
# 0  {'Start': '2023-09-21T09:40:31.024Z', 'End': '...
# 1  {'Start': '2023-09-21T09:40:31.024Z', 'End': '...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((23.6438298900325...
# 1  geography'SRID=4326;POLYGON ((22.6793206704832...
#
#                                         GeoFootprint
# 0  {'type': 'Polygon', 'coordinates': [[[23.64382...
# 1  {'type': 'Polygon', 'coordinates': [[[22.67932...

# %%
#Login info
username = ''
password = ''


auth_server_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
data = {
    "client_id": "cdse-public",
    "grant_type": "password",
    "username": username,
    "password": password,
}

response = requests.post(auth_server_url, data=data, verify=True, allow_redirects=False)
access_token = json.loads(response.text)["access_token"]
# Establish session
session = requests.Session()
session.headers["Authorization"] = f"Bearer {access_token}"

product_row_id = 0   # 0 for the first product in the list
product_id = result.iloc[product_row_id, 1]
print(product_id)
product_name = result.iloc[product_row_id, 2]
print(product_name)

url_MTD = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes(MTD_MSIL2A.xml)/$value"
response = session.get(url_MTD, allow_redirects=False)
while response.status_code in (301, 302, 303, 307):
    url_MTD_location = response.headers["Location"]
    response = session.get(url_MTD_location, allow_redirects=False)

file = session.get(url_MTD_location, verify=False, allow_redirects=True)

# Save the product in home directory
outfile = Path("/content/MTD_MSIL2A.xml")
outfile.write_bytes(file.content)
# Out:
# 1de62670-72bc-42dc-9e42-1c0c7c5d8ba9
# S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE
# 54859

# %%
# Pass the path of the xml document
tree = ET.parse(str(outfile))
# get the parent tag
root = tree.getroot()

# Get the location of individual bands in Sentinel-2 granule
band_path = []
band_path.append(f"{product_name}/{root[0][0][12][0][0][0].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][1].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][2].text}.jp2".split("/"))
band_path.append(f"{product_name}/{root[0][0][12][0][0][3].text}.jp2".split("/"))

# %%
band_path
# Out:
# [['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B02_10m.jp2'],
#  ['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B03_10m.jp2'],
#  ['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B04_10m.jp2'],
#  ['S2A_MSIL2A_20230921T094031_N0509_R036_T35VLD_20230921T151458.SAFE',
#   'GRANULE',
#   'L2A_T35VLD_A043076_20230921T094329',
#   'IMG_DATA',
#   'R10m',
#   'T35VLD_20230921T094031_B08_10m.jp2']]

# %%
# Build the url
for band_node in band_path:
    url_full = f"{url_dataspace}/Products({product_id})/Nodes({product_name})/Nodes({band_node[1]})/Nodes({band_node[2]})/Nodes({band_node[3]})/Nodes({band_node[4]})/Nodes({band_node[5]})/$value"
    #print(url_full)
    response = session.get(url_full, allow_redirects=False)
    while response.status_code in (301, 302, 303, 307):
        url_full_location = response.headers["Location"]
        response = session.get(url_full_location, allow_redirects=False)
    file = session.get(url_full_location, verify=False, allow_redirects=True)
    # Save the product
    outfile =Path("/content/"+band_node[5])
    outfile.write_bytes(file.content)
    print("Saved:", band_node[5])
# Out:
# Saved: T35VLD_20230921T094031_B02_10m.jp2
# Saved: T35VLD_20230921T094031_B03_10m.jp2
# Saved: T35VLD_20230921T094031_B04_10m.jp2
# Saved: T35VLD_20230921T094031_B08_10m.jp2

# %%
# Read the shapefile
aoi_geom = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp')

# Get a list of input files
input_files = glob.glob('T35VLD_*_B0[2-8]_10m.jp2')
input_files = sorted(input_files, reverse=True)
print(input_files)

# Read the CRS from one of the input files
with rasterio.open(input_files[0]) as src:
    input_crs = src.crs

# Convert the AOI polygon to the input CRS
aoi_geom = aoi_geom.to_crs(input_crs)

band_mapping = {
    "B02": "blue",
    "B03": "green",
    "B04": "red",
    "B08": "infra-red",
}

# Clip and save each band individually
output_files = []
for i, input_file in enumerate(input_files):
    band_name = input_file.split('_')[-2].split('.')[0]
    with rasterio.open(input_file) as src:
        # Clip the image
        out_image, out_transform = mask(src, aoi_geom.geometry, crop=True)

        # Update the metadata
        out_meta = src.meta.copy()
        out_meta.update({"driver": "GTiff",
                         "height": out_image.shape[1],
                         "width": out_image.shape[2],
                         "transform": out_transform})

        # Save the clipped image as a GeoTIFF
        output_file = f"clipped_{band_name}.tif"
        with rasterio.open(output_file, "w", **out_meta) as dest:
            dest.write(out_image)

        output_files.append(output_file)

# Stack the RGB bands (B02, B03, B04)
rgb_files = [f"clipped_{band_name}.tif" for band_name in ["B02", "B03", "B04"]]
stacked_meta = out_meta.copy()
stacked_meta.update({"count": len(rgb_files)})

stacked_array = None
for rgb_file in rgb_files:
    with rasterio.open(rgb_file) as src:
        band_array = src.read()
        if stacked_array is None:
            stacked_array = band_array
        else:
            stacked_array = np.concatenate((stacked_array, band_array), axis=0)

# Save the stacked RGB array as a GeoTIFF
with rasterio.open("stacked_SR.tif", "w", **stacked_meta) as dest:
    dest.write(stacked_array)
    dest.descriptions = ("blue", "green", "red")

# Plot the stacked RGB image
with rasterio.open("stacked_SR.tif") as src:
    show(src)
# Out:
# ['T35VLD_20230921T094031_B08_10m.jp2', 'T35VLD_20230921T094031_B04_10m.jp2', 'T35VLD_20230921T094031_B03_10m.jp2', 'T35VLD_20230921T094031_B02_10m.jp2']

# %%
# Image histogramm visualisation
with rasterio.open("stacked_SR.tif") as src:
    rasterio.plot.show_hist(src, bins=50, histtype='stepfilled', lw=0.0, stacked=False, alpha=0.3)

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Stretch each band by standard deviation
def stretch_by_std(band):
    band_mean, band_std = band.mean(), band.std()
    lower_bound = band_mean - 0.5 * band_std
    upper_bound = band_mean + 2 * band_std
    return np.clip((band - lower_bound) / (upper_bound - lower_bound), 0, 1)

# Read bands
blue = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stretch each band by standard deviation
blue_stretched = stretch_by_std(blue)
red_stretched = stretch_by_std(red)
green_stretched = stretch_by_std(green)

# Stack stretched bands
nrg_stretched = np.dstack((blue_stretched, red_stretched, green_stretched))

# View the color composite
plt.imshow(nrg_stretched)
plt.show()

# %%
# Read the shapefile
shapefile_path = '/content/drive/MyDrive/Colab Notebooks/5.prakt.darbam/Apkaimes_rob.shp'
gdf = gpd.read_file(shapefile_path)

# Get the bounding box from the GeoDataFrame
bbox = gdf.total_bounds
print(bbox)

#*****************************************************
#Koda sadaļa, ja vektorfaila crs nesakrīt ar rastra crs

# Define the coordinate systems
shapefile_crs = gdf.crs
wgs84_crs = Proj(init='epsg:4326')  # WGS84 CRS

# Transform bounding box to WGS84
lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

#*****************************************************

# Create bounding box in degrees
degree_bbox = [[lon_min, lat_min], [lon_max, lat_max]]

print(degree_bbox)
# Out:
# [495970.00011127 301544.73713625 519750.20311127 326980.43613624]
# [[20.588349183680297, 58.55880806755003], [21.006649164823802, 58.78294868987171]]
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <ipython-input-193-66f3e7f24d82>:17: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_min, lat_min = transform(shapefile_crs, wgs84_crs, bbox[0], bbox[1])
# <ipython-input-193-66f3e7f24d82>:18: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon_max, lat_max = transform(shapefile_crs, wgs84_crs, bbox[2], bbox[3])

# %%
# Open the file
raster = rasterio.open('/content/stacked_SR.tif')

# Read bands
nir = raster.read(3)
red = raster.read(2)
green = raster.read(1)

# Stack bands
nrg = np.dstack((nir, red, green))

# Normalize the RGB data
nrg_normalized = nrg / nrg.max()

# Create a folium map
m = folium.Map(location=[aoi_point.y, aoi_point.x], zoom_start=11)


# Normalize the RGB data
nrg_normalized = (nrg / nrg.max() * 255).astype(np.uint8)

# Apply histogram equalization independently to each channel
nrg_equalized = np.zeros_like(nrg_normalized)
for i in range(3):
    nrg_equalized[:, :, i] = cv2.equalizeHist(nrg_normalized[:, :, i])

# Save the image with transparency
cv2.imwrite('/content/temp_image.png', cv2.cvtColor(nrg_equalized, cv2.COLOR_RGB2BGR))

temp_jpeg_path = '/content/temp_image.png'

# Add the JPEG image as an overlay
folium.raster_layers.ImageOverlay(
    image=temp_jpeg_path,
    bounds= aoi_circle.bounds,  # Assuming 'aoi_circle' is your circular area
    opacity=1,
    name='Sentinel-2 RGB',  # Name for the layer
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)
m

# %%
#Selecting the channels
b4 = rasterio.open('/content/clipped_B04.tif') # Opening the red channel
b8 = rasterio.open('/content/clipped_B08.tif') # Opening the infra-red channel

red = b4.read(1).astype(float)
nir = b8.read(1).astype(float)

#Check the image stats to see wether we will encounter 0 values for our division || Yes, we will --> our image is partially masked
print("NIR Stats:", np.min(nir), np.max(nir), np.mean(nir))
print("Red Stats:", np.min(red), np.max(red), np.mean(red))

# Add a small constant to the denominator to avoid division by zero
denominator = (nir + red) + 0.0001

# Calculate NDVI, setting NaN for cases where the denominator is zero
ndvi = np.where(denominator == 0, np.nan, (nir - red) / denominator)

# Prepare metadata
meta = b4.meta
meta.update(driver='GTiff')
meta.update(dtype=rasterio.float32, count=1)

# Save NDVI as GeoTIFF
with rasterio.open('NDVI.tif', 'w', **meta) as dst:
    dst.write(ndvi.astype(rasterio.float32), 1)
# Out:
# NIR Stats: 0.0 16576.0 1407.08427734359
# Red Stats: 0.0 17120.0 720.8111870825915

# %%
# Open the NDVI GeoTIFF file
ndvi_file = '/content/NDVI.tif'
with rasterio.open(ndvi_file) as src:
    ndvi = src.read(1)

# Plot the NDVI image and Set the figure size
plt.figure(figsize=(12, 12))
plt.imshow(ndvi, cmap='inferno', extent=[raster.bounds.left, raster.bounds.right, raster.bounds.bottom, raster.bounds.top])
plt.colorbar(label='NDVI')
plt.title('NDVI Image')
plt.show()

# %%
from shapely.geometry import Point
import geopandas as gpd
from fiona.crs import from_epsg

# Coordinates of the center of the circle
circle_center = Point(24.1057, 56.9483)

# Create a circular area with a radius of 500 meters
aoi_circle = circle_center.buffer(0.005)  # Assuming 0.005 degrees is approximately 500 meters

# Open the NDVI GeoTIFF file
ndvi_file = 'NDVI.tif'
with rasterio.open(ndvi_file) as ndvi_src:
    # Convert the circular area to GeoDataFrame
    circle_gdf = gpd.GeoDataFrame(geometry=[aoi_circle], crs=from_epsg(4326))

    # Reproject the GeoDataFrame to match the raster CRS
    circle_gdf = circle_gdf.to_crs(ndvi_src.crs)

    # Use rasterstats to calculate zonal statistics (mean, median, min, max NDVI)
    stats = zonal_stats(circle_gdf.geometry, ndvi_file, stats=["mean", "median", "min", "max"], nodata=np.nan)

    # Extract the statistics values
    mean_ndvi = stats[0]['mean']
    median_ndvi = stats[0]['median']
    min_ndvi = stats[0]['min']
    max_ndvi = stats[0]['max']

# Print the statistics values
print(f"Mean NDVI Value: {mean_ndvi}")
print(f"Median NDVI Value: {median_ndvi}")
print(f"Min NDVI Value: {min_ndvi}")
print(f"Max NDVI Value: {max_ndvi}")
# Out:
# Mean NDVI Value: 0.06938752086734754
# Median NDVI Value: 0.030478954315185547
# Min NDVI Value: -0.08359582722187042
# Max NDVI Value: 0.5999999642372131

# %% [markdown]
# Mean NDVI Value: 0.06938752086734754 # ar apli
#
# Mean NDVI Value: 0.15663705100301603 # ar kvadrātu
#
# Mean NDVI Value: 0.18868432836219712 # 1 variants
#
# ------------------------------------------------------
#
# Median NDVI Value: 0.030478954315185547 # ar apli
#
# Median NDVI Value: 0.1048344224691391 # ar kvadrātu
#
# Median NDVI Value: 0.13751116394996643 # 1 variants
#
# ------------------------------------------------------
#
# Min NDVI Value: -0.08359582722187042 # ar apli
#
# Min NDVI Value: -0.10279694944620132 # ar kvadrātu
#
# Min NDVI Value: -0.09742441028356552 # 1 variants
#
# ------------------------------------------------------
#
# Max NDVI Value: 0.5999999642372131 # ar apli
#
# Max NDVI Value: 0.5815714597702026 # ar kvadrātu
#
# Max NDVI Value: 0.6658543348312378 # 1 variants
